# %%
import numpy as np

# %%
import tensorflow as tf
import os
import cv2
import random

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
# import matplotlib.pyplot as plt

# %%
seed_constant = 15
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
image_height, image_width = 64, 64
max_images_per_class = 8000
 
dataset_directory = "dataset"

classes_list = ["Fighting","Shooting","RoadAccidents","Robbery","Abuse","Arrest","Arson","Assault","Burglary","Explosion","Normal"]

 
model_output_size = len(classes_list)

# %%
model_output_size
# Out:
# 11

# %%
def frames_extraction(video_path):
    # Empty List declared to store video frames
    frames_list = []
     
    # Reading the Video File Using the VideoCapture
    video_reader = cv2.VideoCapture(video_path)
 
    # Iterating through Video Frames
    while True:
 
        # Reading a frame from the video file 
        success, frame = video_reader.read() 
 
        # If Video frame was not successfully read then break the loop
        if not success:
            break
 
        # Resize the Frame to fixed Dimensions
        resized_frame = cv2.resize(frame, (image_height, image_width))
        # print(video_path)
         
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
         
        # Appending the normalized frame into the frames list
        frames_list.append(normalized_frame)
     
    # Closing the VideoCapture object and releasing all resources. 
    video_reader.release()
 
    # returning the frames list 
    return frames_list

# %%
# import moviepy.editor as mp

# %%
# def resize(video_path):

 
#         # Resize the Frame to fixed Dimensions
#     clip = mp.VideoFileClip(video_path)
#     clip_resized = clip.resize(height=64)
#     clip_resized.write_videofile(video_path)

# %%
# path="C:/Users/rudra/Downloads/cctv_analysis/dataset/Anomaly-Videos-Part-3"
# for classes in classes_list:
#     temp_path=os.path.join(path,classes)
#     for videos in os.listdir(temp_path):
#         print(videos)
#         video_path=os.path.join(temp_path,videos)
#         print(video_path)
#         resize(video_path)

# %%
def create_dataset():
 
    # Declaring Empty Lists to store the features and labels values.
    temp_features = [] 
    features = []
    
    labels = []
    dataset_directory = "C:/Users/rudra/Downloads/cctv_2/dataset"
     
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(classes_list):
        print(f'Extracting Data of Class: {class_name}')
         
        # Getting the list of video files present in the specific class name directory
        files_list = os.listdir(os.path.join(dataset_directory, class_name))
 
        # Iterating through all the files present in the files list
        for file_name in files_list:
 
            # Construct the complete video path
            video_file_path = os.path.join(dataset_directory, class_name, file_name)
            
 
            # Calling the frame_extraction method for every video file path
#             resize(video_file_path)
            frames = frames_extraction(video_file_path)
            print(video_file_path)
 
            # Appending the frames to a temporary list.
            temp_features.extend(frames)
         
        # Adding randomly selected frames to the features list
        features.extend(random.sample(temp_features, max_images_per_class))
 
        # Adding Fixed number of labels to the labels list
        labels.extend([class_index] * max_images_per_class)
         
        # Emptying the temp_features list so it can be reused to store all frames of the next class.
        temp_features.clear()
 
    # Converting the features and labels lists to numpy arrays
    # features = np.asarray(features)
    # labels = np.array(labels)  
    # a = np.asarray(features)
    np.save("features.npy",features)
    # b = np.asarray(labels)
    np.save("labels.npy",labels)
 
    # return features, labels

# %%
# features, labels = create_dataset()
create_dataset()
# Out:
# Extracting Data of Class: Fighting
# C:/Users/rudra/Downloads/cctv_2/dataset\Fighting\Fighting002_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\
mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_745_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_758_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_758_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_781_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_781_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_798_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_798_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_801_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_801_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_828_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_828_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_831_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_831_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_877_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_877_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_881_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_881_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_885_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_885_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_892_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_892_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_905_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_905_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_912_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_912_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_913_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_913_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_914_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_914_x264.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_929_x264 - Copy.mp4
# C:/Users/rudra/Downloads/cctv_2/dataset\Normal\Normal_Videos_929_x264.mp4

# %%
features = np.load("features.npy")
labels = np.load("labels.npy")

# %%
import pandas as pd

# %%
from tensorflow.keras.utils import to_categorical
one_hot_encoded_labels = to_categorical(labels)

# %%
print(labels)
# Out:
# [ 0  0  0 ... 10 10 10]

# %%
from sklearn.model_selection import train_test_split

# %%
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.2, shuffle = True, random_state = seed_constant)

# %%
features_test.shape
# Out:
# (17600, 64, 64, 3)

# %%
def create_model():
 
    # We will use a Sequential model for model construction
    model = Sequential()
 
    # Defining The Model Architecture
    model.add(Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu', input_shape = (image_height, image_width, 3)))
    model.add(Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(GlobalAveragePooling2D())
    model.add(Dense(256, activation = 'relu'))
    model.add(BatchNormalization())
    model.add(Dense(model_output_size, activation = 'softmax'))
 
    # Printing the models summary
    model.summary()
 
    return model
 
 
# Calling the create_model method
model = create_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        36928
#
#  batch_normalization (BatchN  (None, 60, 60, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 64)       0
#  )
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               16640
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 59,467
# Trainable params: 58,827
# Non-trainable params: 640
# _________________________________________________________________

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)
 
# Adding loss, optimizer and metrics values to the model.
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])
 
# Start Training
model_training_history = model.fit(x = features_train, y = labels_train, epochs = 20, batch_size = 4 , shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/20
# 14080/14080 [==============================] - 682s 48ms/step - loss: 1.6696 - accuracy: 0.4594 - val_loss: 1.5941 - val_accuracy: 0.6149
# Epoch 2/20
# 14080/14080 [==============================] - 655s 47ms/step - loss: 1.0261 - accuracy: 0.6885 - val_loss: 1.3060 - val_accuracy: 0.6880
# Epoch 3/20
# 14080/14080 [==============================] - 667s 47ms/step - loss: 0.7885 - accuracy: 0.7638 - val_loss: 1.5330 - val_accuracy: 0.7391
# Epoch 4/20
# 14080/14080 [==============================] - 666s 47ms/step - loss: 0.6658 - accuracy: 0.8025 - val_loss: 2.4630 - val_accuracy: 0.6765
# Epoch 5/20
# 14080/14080 [==============================] - 664s 47ms/step - loss: 0.5899 - accuracy: 0.8260 - val_loss: 0.8009 - val_accuracy: 0.8541
# Epoch 6/20
# 14080/14080 [==============================] - 655s 46ms/step - loss: 0.5331 - accuracy: 0.8428 - val_loss: 0.9090 - val_accuracy: 0.8317
# Epoch 7/20
# 14080/14080 [==============================] - 630s 45ms/step - loss: 0.4999 - accuracy: 0.8550 - val_loss: 0.6684 - val_accuracy: 0.8974
# Epoch 8/20
# 14080/14080 [==============================] - 629s 45ms/step - loss: 0.4724 - accuracy: 0.8626 - val_loss: 1.6936 - val_accuracy: 0.7462
# Epoch 9/20
# 14080/14080 [==============================] - 685s 49ms/step - loss: 0.4447 - accuracy: 0.8708 - val_loss: 0.6794 - val_accuracy: 0.8871
# Epoch 10/20
# 14080/14080 [==============================] - 658s 47ms/step - loss: 0.4165 - accuracy: 0.8788 - val_loss: 0.5725 - val_accuracy: 0.9101
# Epoch 11/20
# 14080/14080 [==============================] - 625s 44ms/step - loss: 0.4075 - accuracy: 0.8815 - val_loss: 0.8604 - val_accuracy: 0.8750
# Epoch 12/20
# 14080/14080 [==============================] - 632s 45ms/step - loss: 0.4029 - accuracy: 0.8829 - val_loss: 0.5352 - val_accuracy: 0.9343
# Epoch 13/20
# 14080/14080 [==============================] - 633s 45ms/step - loss: 0.3824 - accuracy: 0.8888 - val_loss: 0.6955 - val_accuracy: 0.9097
# Epoch 14/20
# 14080/14080 [==============================] - 631s 45ms/step - loss: 0.3680 - accuracy: 0.8942 - val_loss: 0.4853 - val_accuracy: 0.9326
# Epoch 15/20
# 14080/14080 [==============================] - 623s 44ms/step - loss: 0.3486 - accuracy: 0.8986 - val_loss: 1.1951 - val_accuracy: 0.8975
# Epoch 16/20
# 14080/14080 [==============================] - 624s 44ms/step - loss: 0.3456 - accuracy: 0.9002 - val_loss: 0.8739 - val_accuracy: 0.8911
# Epoch 17/20
# 14080/14080 [==============================] - 619s 44ms/step - loss: 0.3435 - accuracy: 0.9006 - val_loss: 0.7356 - val_accuracy: 0.9175
# Epoch 18/20
# 14080/14080 [==============================] - 618s 44ms/step - loss: 0.3334 - accuracy: 0.9026 - val_loss: 1.4435 - val_accuracy: 0.8887
# Epoch 19/20
# 14080/14080 [==============================] - 619s 44ms/step - loss: 0.3270 - accuracy: 0.9038 - val_loss: 2.2701 - val_accuracy: 0.8805
# Epoch 20/20
# 14080/14080 [==============================] - 621s 44ms/step - loss: 0.3279 - accuracy: 0.9038 - val_loss: 0.6993 - val_accuracy: 0.9143

# %%
print(model_training_history)
# Out:
# <keras.callbacks.History object at 0x0000023680172130>

# %%
model.save('model_8000.h5')

# %%
model = tf.keras.models.load_model('model_8000.h5')

# %%
model_evaluation_history = model.evaluate(features_test, labels_test)
# Out:
# 550/550 [==============================] - 31s 57ms/step - loss: 0.7197 - accuracy: 0.9109

# %%
def plot_metric(metric_name_1, metric_name_2, plot_name):
  # Get Metric values using metric names as identifiers
  metric_value_1 = model_training_history.history[metric_name_1]
  metric_value_2 = model_training_history.history[metric_name_2]
 
  # Constructing a range object which will be used as time 
  epochs = range(len(metric_value_1))
   
  # Plotting the Graph
  plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
  plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)
   
  # Adding title to the plot
  plt.title(str(plot_name))
 
  # Adding legend to the plot
  plt.legend()

# %%
plot_metric('loss', 'val_loss', 'Total Loss vs Total Validation Loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plot_metric('loss', 'val_loss', 'Total Loss vs Total Validation Loss')
#
# Cell In[19], line 3, in plot_metric(metric_name_1, metric_name_2, plot_name)
#       1 def plot_metric(metric_name_1, metric_name_2, plot_name):
#       2   # Get Metric values using metric names as identifiers
# ----> 3   metric_value_1 = model_training_history.history[metric_name_1]
#       4   metric_value_2 = model_training_history.history[metric_name_2]
#       6   # Constructing a range object which will be used as time
#
# NameError: name 'model_training_history' is not defined

# %%
from collections import deque

# %%
# def save_video(frames):

# %%
def save_clip(frames):
    height, width, _ = frames[0].shape
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")  
    frame_rate=30
    output_video = cv2.VideoWriter("C:/Users/rudra/Downloads/output_clip.mp4", fourcc, frame_rate, (width, height))

    for frame in frames:
        output_video.write(frame)
    output_video.release()

# %%
def predict_on_live_video(video_file_path, output_file_path, window_size):
    frame_count=0
    frames=[]
    # Initialize a Deque Object with a fixed size which will be used to implement moving/rolling average functionality.
    predicted_labels_probabilities_deque = deque(maxlen = window_size)
 
    # Reading the Video File using the VideoCapture Object
#     video_reader = cv2.VideoCapture(video_file_path)
    video_reader = cv2.VideoCapture(video_file_path)
 
    # Getting the width and height of the video 
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))
 
    # Writing the Overlayed Video Files Using the VideoWriter Object
    video_writer = cv2.VideoWriter(output_file_path, cv2.VideoWriter_fourcc('M', 'P', '4', 'V'), 24, (original_video_width, original_video_height))
 
    while True: 
 
        # Reading The Frame
        status, frame = video_reader.read() 
 
        if not status:
            break
 
        # Resize the Frame to fixed Dimensions
        resized_frame = cv2.resize(frame, (image_height, image_width))
         
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
 
        # Passing the Image Normalized Frame to the model and receiving Predicted Probabilities.
        predicted_labels_probabilities = model.predict(np.expand_dims(normalized_frame, axis = 0))[0]
 
        # Appending predicted label probabilities to the deque object
        predicted_labels_probabilities_deque.append(predicted_labels_probabilities)
 
        # Assuring that the Deque is completely filled before starting the averaging process
        if len(predicted_labels_probabilities_deque) == window_size:
 
            # Converting Predicted Labels Probabilities Deque into Numpy array
            predicted_labels_probabilities_np = np.array(predicted_labels_probabilities_deque)
 
            # Calculating Average of Predicted Labels Probabilities Column Wise 
            predicted_labels_probabilities_averaged = predicted_labels_probabilities_np.mean(axis = 0)
 
            # Converting the predicted probabilities into labels by returning the index of the maximum value.
            predicted_max=np.max(predicted_labels_probabilities_averaged)
            predicted_label = np.argmax(predicted_labels_probabilities_averaged)
            print(predicted_max)
            if predicted_max>0.6 and predicted_label<10:
                predicted_label = np.argmax(predicted_labels_probabilities_averaged)
                frame_count=frame_count+1
                if frame_count<450:
                    frames.append(frame)
                else:
                    if len(frames)>100:
                        save_clip(frames)
                    frame_count=0
                    frames=[]
            else:
                predicted_label=10 
            # Accessing The Class Name using predicted label.
            predicted_class_name = classes_list[predicted_label]

           
            # Overlaying Class Name Text Ontop of the Frame
            # cv2.putText(frame, predicted_class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
            print(predicted_class_name)
 
        # Writing The Frame
        video_writer.write(frame)
 
 
        cv2.imshow('Predicted Frames', frame)
 
        key_pressed = cv2.waitKey(10)
 
        if key_pressed == ord('q'):
            break
 
    cv2.destroyAllWindows()
 
     
    # Closing the VideoCapture and VideoWriter objects and releasing all resources held by them. 
    video_reader.release()
    video_writer.release()

# %%
output_file_path = "C:/Users/rudra/OneDrive/Desktop"
# output_file_path = 0
window_size = 30
video_file_path = "C:/Users/rudra/Downloads/cctv_2/dataset/Explosion/Explosion003_x264.mp4"
predict_on_live_video(video_file_path, output_file_path, window_size)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 0.9263074
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9252349
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9242799
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9249436
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.92448676
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.92398745
# Explosion
# 1/1 [==============================] - 0s 27ms/step
# 0.92312175
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9238346
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9239246
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9244405
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.92631346
# Explosion
# 1/1 [==============================] - 0s 27ms/step
# 0.92779756
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.92304224
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9186093
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9179146
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9173203
# Explosion
# 1/1 [==============================] - 0s 30ms/step
# 0.91999316
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9229338
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.926795
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.92516345
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9207741
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.91497844
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.91481125
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9146298
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9156101
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.91655356
# Explosion
# 1/1 [==============================] - 0s 25ms/step
# 0.9094773
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8998874
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.89481163
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.88968843
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8878888
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8907121
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.892644
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.89451957
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.89760715
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9008258
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9056787
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9082363
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9103267
# Explosion
# 1/1 [==============================] - 0s 33ms/step
# 0.91082495
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.91119635
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9115707
# Explosion
# 1/1 [==============================] - 0s 27ms/step
# 0.91839194
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9240969
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.9258586
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.92587817
# Explosion
# 1/1 [==============================] - 0s 72ms/step
# 0.9247908
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.92373395
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.92334265
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9266087
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9301579
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9332281
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9275573
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.92203385
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.91538256
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.9033556
# Explosion
# 1/1 [==============================] - 0s 29ms/step
# 0.8994148
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.90262455
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.90282494
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.90303856
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.90332633
# Explosion
# 1/1 [==============================] - 0s 23ms/step
# 0.9013117
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.89636075
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8914878
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.88743204
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.8832779
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.88043195
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.87592596
# Explosion
# 1/1 [==============================] - 0s 33ms/step
# 0.87140155
# Explosion
# 1/1 [==============================] - 0s 25ms/step
# 0.86832446
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.86546516
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8627051
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8602715
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.85666573
# Explosion
# 1/1 [==============================] - 0s 33ms/step
# 0.85712916
# Explosion
# 1/1 [==============================] - 0s 31ms/step
# 0.8583042
# Explosion
# 1/1 [==============================] - 0s 40ms/step
# 0.85831165
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.85820305
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.85729
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.8558046
# Explosion
# 1/1 [==============================] - 0s 42ms/step
# 0.85397035
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8555706
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.85986733
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.86383665
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.86753553
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.87627035
# Explosion
# 1/1 [==============================] - 0s 26ms/step
# 0.8862821
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.89049727
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8908028
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.89098155
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8894059
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.8676639
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.8494238
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.82260007
# Explosion
# 1/1 [==============================] - 0s 48ms/step
# 0.7945792
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.7668365
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.73917407
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.7326602
# Explosion
# 1/1 [==============================] - 0s 31ms/step
# 0.7273878
# Explosion
# 1/1 [==============================] - 0s 25ms/step
# 0.7088364
# Explosion
# 1/1 [==============================] - 0s 25ms/step
# 0.6895662
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6696593
# Explosion
# 1/1 [==============================] - 0s 33ms/step
# 0.66966385
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.66823035
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6538296
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.6406733
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.6325478
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6255721
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.6169783
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6114555
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.60161316
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.60249484
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6039899
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.60579735
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.6081559
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6099065
# Explosion
# 1/1 [==============================] - 0s 64ms/step
# 0.6117255
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.61156833
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6151026
# Explosion
# 1/1 [==============================] - 0s 23ms/step
# 0.6188353
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.62139297
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.64164346
# Explosion
# 1/1 [==============================] - 0s 28ms/step
# 0.6618644
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.6928025
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.718758
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.74440557
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.76795125
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.77004045
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.76965076
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.7807129
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.8029759
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.8258459
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.8286717
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.83334595
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.84761536
# Explosion
# 1/1 [==============================] - 0s 33ms/step
# 0.8474172
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.8477577
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.84701735
# Explosion
# 1/1 [==============================] - 0s 72ms/step
# 0.84183884
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.83912635
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.82469696
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.7978383
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.7770365
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.756734
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.7335295
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.7180586
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.705845
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6903641
# Explosion
# 1/1 [==============================] - 0s 27ms/step
# 0.6763379
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.66243345
# Explosion
# 1/1 [==============================] - 0s 33ms/step
# 0.659291
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.65959615
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6517052
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.6427326
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.623422
# Explosion
# 1/1 [==============================] - 0s 24ms/step
# 0.6039029
# Explosion
# 1/1 [==============================] - 0s 32ms/step
# 0.5840507
# Normal
# 1/1 [==============================] - 0s 32ms/step
# 0.57658106
# Normal
# 1/1 [==============================] - 0s 22ms/step
# 0.5671766
# Normal
# 1/1 [==============================] - 0s 48ms/step
# 0.5645683
# Normal
# 1/1 [==============================] - 0s 24ms/step
# 0.5432352
# Normal
# 1/1 [==============================] - 0s 24ms/step
# 0.5206053
# Normal
# 1/1 [==============================] - 0s 24ms/step
# 0.48924106
# Normal
# 1/1 [==============================] - 0s 24ms/step
# 0.4881388
# Normal
# 1/1 [==============================] - 0s 30ms/step
# 0.51757795
# Normal
# 1/1 [==============================] - 0s 28ms/step
# 0.5348552
# Normal
# 1/1 [==============================] - 0s 32ms/step
# 0.55431676
# Normal
# 1/1 [==============================] - 0s 24ms/step
# 0.57383025
# Normal
# 1/1 [==============================] - 0s 32ms/step
# 0.5867488
# Normal
# 1/1 [==============================] - 0s 24ms/step
# 0.610146
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.6170463
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.61859745
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.6255476
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.6320098
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.6348738
# Fighting
# 1/1 [==============================] - 0s 33ms/step
# 0.6383189
# Fighting
# 1/1 [==============================] - 0s 31ms/step
# 0.65045625
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.65147483
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.66718954
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.683193
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.70876783
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.73642415
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.75735897
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.7724225
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.7711342
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.7694984
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.7728002
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.7883701
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.8001732
# Fighting
# 1/1 [==============================] - 0s 40ms/step
# 0.81993616
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.83204633
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.84272754
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.84220475
# Fighting
# 1/1 [==============================] - 0s 28ms/step
# 0.8429123
# Fighting
# 1/1 [==============================] - 0s 27ms/step
# 0.84313804
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.8405384
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.837882
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.834555
# Fighting
# 1/1 [==============================] - 0s 28ms/step
# 0.8236482
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.80647874
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.79974693
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.8033417
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.804642
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.80692804
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.8113952
# Fighting
# 1/1 [==============================] - 0s 25ms/step
# 0.8215649
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.8288137
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.8415387
# Fighting
# 1/1 [==============================] - 0s 25ms/step
# 0.84275573
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.84377927
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.8461456
# Fighting
# 1/1 [==============================] - 0s 28ms/step
# 0.8433731
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.83447754
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.8300755
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.83415693
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.8376535
# Fighting
# 1/1 [==============================] - 0s 29ms/step
# 0.8349855
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.8327713
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.82403183
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.8105676
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.7969811
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.78314817
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.7753833
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.7638472
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.755266
# Fighting
# 1/1 [==============================] - 0s 22ms/step
# 0.75512713
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.75339997
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.7523688
# Fighting
# 1/1 [==============================] - 0s 25ms/step
# 0.7604097
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.7601836
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.75208145
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.7359838
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.724588
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.7128335
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.70154285
# Fighting
# 1/1 [==============================] - 0s 34ms/step
# 0.69391876
# Fighting
# 1/1 [==============================] - 0s 40ms/step
# 0.690011
# Fighting
# 1/1 [==============================] - 0s 24ms/step
# 0.68624496
# Fighting
# 1/1 [==============================] - 0s 32ms/step
# 0.6825283
# Fighting
